# %% [markdown]
# # Kepler's Laws of Planetary Motion
#
# ## Authors
# B.W. Holwerda
#
# ## Learning Goals
# * Three Kepler's Laws
# * Link with Newton's Gravity
#
# ## Keywords
#
# ## Companion Content
#
# Chapter 3 in Ryden & Peterson
#
# Chapter 2 in Carroll & Ostlie
#
# ## Summary
#
# Using an animation example, build the Solar System for Kepler's Second Law, an animation mp4, and lastly a plot of the period-major axes of the Solar System to illustrate Kepler's third law.
#
# <hr>

# %% [markdown]
# ## Student Name and ID:
#
#
#
# ## Date:
#
# <hr>

# %%
import numpy as np

import matplotlib.pyplot as plt
from matplotlib import rcParams
rcParams["savefig.dpi"] = 150
rcParams["figure.dpi"] = 150
rcParams["font.size"] = 15

from astropy.coordinates import SkyCoord
from astropy import units as u

# %% [markdown]
# # Kepler's Laws
#
# Kepler's laws of planetary motion describe the orbits of planets around the Sun. The laws modified the heliocentric (Sun at the center of the Solar System) theory of Nicolaus Copernicus, replacing its *circular* orbits and *epicycles* with *elliptical trajectories*, and explaining how planetary velocities vary. The three laws state that:
#
# * The orbit of a planet is an ellipse with the Sun at one of the two foci.
# * A line segment joining a planet and the Sun sweeps out equal areas during equal intervals of time.
# * The square of a planet's orbital period is proportional to the cube of the length of the semi-major axis of its orbit.
#
# The elliptical orbits of planets were indicated by calculations of the orbit of Mars. From this, Kepler inferred that other bodies in the Solar System, including those farther away from the Sun, also have elliptical orbits. The second law helps to establish that when a planet is closer to the Sun, it travels faster. The third law expresses that the farther a planet is from the Sun, the slower its orbital speed.
#
# Below we plot an elliptical orbit where the center is x=1 y=0.5 with a and b are the major and minor axes.

# %%
import numpy as np
from matplotlib import pyplot as plt
from math import pi

u=1.     #x-position of the center
v=0.5    #y-position of the center
a=2.     #radius on the x-axis
b=1.5    #radius on the y-axis

fig = plt.figure(figsize=(4,4))
c = np.sqrt(a*a - b*b)
t = np.linspace(0, 2*pi, 100)
plt.plot( u+a*np.cos(t) , v+b*np.sin(t) )
plt.plot(c,v,'k.')
plt.grid(color='lightgray',linestyle='--')
plt.show()

# %% [markdown]
# ### Assignment 1 -- Kepler's First Law: Planets travel on Elliptical Orbits
#
# Here is a list of the eccentricities of the planets in the Solar System. Plot their orbits, converting everything to AU
#
# https://nssdc.gsfc.nasa.gov/planetary/factsheet/

# %%
# student work here

# %% [markdown]
# ### Assignment 2
#
# Can you visually tell these are elliptical orbits?

# %% [markdown]
# *student work here*

# %% [markdown]
# ## Kepler's Second Law:
# ### A planetary orbit sweeps out the same area during travel.
#
# Below you will find an animation of the plot above. Run it and open Kepler_animation.mp4 to see what the end result looks like.

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import animation


u=0.    # x-position of the center
v=0.5     # y-position of the center
a=2.     # radius on the x-axis
b=1.5    # radius on the y-axis

c = np.sqrt(a*a - b*b)

t = np.linspace(0, 2*pi, 1000)
# plt.plot( u+a*np.cos(t) , v+b*np.sin(t) )
# plt.grid(color='lightgray',linestyle='--')
# plt.show()


# First set up the figure, the axis, and the plot element we want to animate
fig = plt.figure()
ax = plt.axes(xlim=(-3, 3), ylim=(-3, 3))
line, = ax.plot([], [], lw=2)
# area, = ax.fill_between([],[],[],color='g',alpha=0.4)


# initialization function: plot the background of each frame
def init():
    line.set_data([], [])
#     area.set_data([], [], [])

    return line,

# animation function.  This is called sequentially
def animate(i):
    t = np.linspace((i-1)*np.pi/3, i*np.pi/3, 100)
    x = u+a*np.cos(t/np.sqrt(a*a*a)) 
    y = v+b*np.sin(t/np.sqrt(a*a*a))
    x = np.concatenate( ([c],x,[c]) )
    y = np.concatenate( (np.zeros(1),y,np.zeros(1)) )    
    line.set_data(x, y)
#     area.set_data([0,x[0],x[-1]], [0,y[0],y[0]],[0,y[0],y[-1]])
    return line,

# call the animator.  blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=200, interval=20, blit=True)

# save the animation as an mp4.  This requires ffmpeg or mencoder to be
# installed.  The extra_args ensure that the x264 codec is used, so that
# the video can be embedded in html5.  You may need to adjust this for
# your system: for more information, see
# http://matplotlib.sourceforge.net/api/animation_api.html
anim.save('Kepler_animation.mp4', fps=12) # , extra_args=['-vcodec', 'libx264'])

plt.show()

# %% [markdown]
# ### Assignment 3
#
# Copy the above code and make a new movie but for a much more elliptical orbit. HINT: you can copy the entire code cell and move it below here.

# %%
# student work below

# %% [markdown]
# # Kepler's Third Law Period-radius
#
# https://nssdc.gsfc.nasa.gov/planetary/factsheet/
#
# Use the values for the solar system for the major axes and the period of the orbit from the NASA factsheet. Plot these values against each other and show that $P^2 = a^3$. Also plot a line of this relation. How close are the planets to this line? HINT: since this is a power law ($P=a^{3/2}$, it might be better to plot this as a log-log plot.

# %%
# student work here
